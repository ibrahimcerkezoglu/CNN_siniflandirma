# %%
import os
from PIL import Image

base_dir = r"C:\Users\ibrah\Documents\BLG407_Proje\dataset"

target_size = (128, 128)

for split in ["train", "test"]:
    for cls in ["sinif1_sise", "sinif2_bardak"]:
        folder = os.path.join(base_dir, split, cls)
        for fname in os.listdir(folder):
            path = os.path.join(folder, fname)
            try:
                img = Image.open(path).convert("RGB")
                img = img.resize(target_size)
                img.save(path)   # aynı dosyanın üzerine yazar
            except Exception as e:
                print("Hata:", path, e)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       9 for cls in ["sinif1_sise", "sinif2_bardak"]:
#      10     folder = os.path.join(base_dir, split, cls)
# ---> 11     for fname in os.listdir(folder):
#      12         path = os.path.join(folder, fname)
#      13         try:
#
# FileNotFoundError: [WinError 3] Sistem belirtilen yolu bulamıyor: 'C:\\Users\\ibrah\\Documents\\BLG407_Proje\\dataset\\train\\sinif2_bardak'
